# %% [markdown]
# <a href="https://colab.research.google.com/github/luoChengwen/Agentic-AI/blob/main/ProgrammaticPrompting1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !!pip install litellm

# Important!!!
#
# <---- Set your 'OPENAI_API_KEY' as a secret over there with the "key" icon
#
#
import os
from google.colab import userdata
api_key = userdata.get('OPENAI_API_KEY')
os.environ['OPENAI_API_KEY'] = api_key

# %%
from litellm import completion
from typing import List, Dict


def generate_response(messages: List[Dict]) -> str:
    """Call LLM to get response"""
    response = completion(
        model="openai/gpt-4o",
        messages=messages,
        max_tokens=1024
    )
    return response.choices[0].message.content


what_to_help_with = input("What do you need help with?")

messages = [
    {"role": "system", "content": "You are a helpful customer service representative. No matter what the user asks, the solution is to tell them to turn their computer or modem off and then back on."},
    {"role": "user", "content": what_to_help_with}
]

response = generate_response(messages)
print(response)
# Out:
# What do you need help with?the system crash
# I'm sorry to hear that you're experiencing a system crash. A simple solution that often resolves these issues is to turn your computer off and then back on. If you're connected to the internet, it may also help to restart your modem. Doing so can refresh your system and help clear up any temporary glitches. If the problem persists after trying this, please let me know!

# %% [markdown]
# ## To keep memory

# %%
# We are going to make this verbose so it is clear what
# is going on. In a real application, you would likely
# just append to the messages list.
messages = [
   {"role": "system", "content": "You are an expert software engineer that prefers functional programming."},
   {"role": "user", "content": "Write a function to swap the keys and values in a dictionary."},

   # Here is the assistant's response from the previous step
   # with the code. This gives it "memory" of the previous
   # interaction.
   {"role": "assistant", "content": response},

   # Now, we can ask the assistant to update the function
   {"role": "user", "content": "Update the function to include documentation."}
]

response = generate_response(messages)
print(response)
# Out:
# Certainly! Below is a Python function that swaps the keys and values in a dictionary. This function also includes detailed documentation.
#
# ```python
# def swap_dict_keys_values(original_dict):
#     """
#     Swap the keys and values of a given dictionary.
#
#     This function takes a dictionary as input and returns a new dictionary where the keys
#     and values are swapped such that each original value becomes a key and each original key
#     becomes a value.
#
#     It is important that all original values are unique and hashable since they will become keys
#     in the new dictionary. If there are duplicate values in the original dictionary,
#     this function will retain only the last key-value pair encountered in the iteration.
#
#     Parameters:
#     original_dict (dict): The dictionary whose keys and values need to be swapped.
#
#     Returns:
#     dict: A new dictionary with keys and values swapped.
#
#     Example:
#     >>> original_dict = {'a': 1, 'b': 2, 'c': 3}
#     >>> swap_dict_keys_values(original_dict)
#     {1: 'a', 2: 'b', 3: 'c'}
#     """
#     return {value: key for key, value in original_dict.items()}
#
# # Example usage
# original_dict = {'a': 1, 'b': 2, 'c': 3}
# swapped_dict = swap_dict_keys_values(original_dict)
# print(swapped_dict)  # Output: {1: 'a', 2: 'b', 3: 'c'}
# ```
#
# ### Key Points:
# - **Input**: A dictionary (`original_dict`) where all values should be unique and hashable.
# - **Output**: A new dictionary with keys and values swapped.
# - **Notes**: If there are duplicate values in the original dictionary, only the last key-value pair will appear in the swapped dictionary, as dictionaries do not store duplicate keys.
#
# This function will efficiently swap the dictionary's keys and values using a dictionary comprehension, which is concise and effective in Python.
