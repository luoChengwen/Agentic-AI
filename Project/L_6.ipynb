# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %%
import zipfile
import os
foler_path ='./L13'
zip_path = './L13.zip'
# !zip -r L_6.zip L_6
import shutil


shutil.make_archive(zip_path, 'zip', folder_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 9
#       5 # !zip -r L_6.zip L_6
#       6 import shutil
# ----> 9 shutil.make_archive(zip_path, 'zip', folder_path)
#
# NameError: name 'folder_path' is not defined

# %%
# !ls
# Out:
# L0_no_notebook	 L1_no_notebook  L6		 requirements.txt
# L10		 L2		 L7_no_notebook  ro_shared_data
# L11_no_notebook  L3_no_notebook  L8
# L12_no_notebook  L4		 L9_no_notebook
# L13		 L5_no_notebook  helper.py

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 156 packages in 1.32s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# rich       ------------------------------     0 B/302.70 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# rich       ------------------------------     0 B/302.70 KiB
# protobuf   ------------------------------     0 B/315.88 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# rich       ------------------------------     0 B/302.70 KiB
# protobuf   ------------------------------     0 B/315.88 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# rich       ------------------------------     0 B/302.70 KiB
# protobuf   ------------------------------     0 B/315.88 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# python-docx ------------------------------     0 B/247.06 KiB
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# rich       ------------------------------     0 B/302.70 KiB
# protobuf   ------------------------------     0 B/315.88 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# openpyxl   ------------------------------     0 B/245.03 KiB
# python-docx ------------------------------     0 B/247.06 KiB
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# rich       ------------------------------     0 B/302.70 KiB
# protobuf   ------------------------------     0 B/315.88 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# openpyxl   ------------------------------     0 B/245.03 KiB
# python-docx ------------------------------     0 B/247.06 KiB
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# rich       ------------------------------     0 B/302.70 KiB
# protobuf   ------------------------------     0 B/315.88 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# openpyxl   ------------------------------     0 B/245.03 KiB
# python-docx ------------------------------     0 B/247.06 KiB
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# rich       ------------------------------     0 B/302.70 KiB
# protobuf   ------------------------------     0 B/315.88 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# lxml       ------------------------------     0 B/4.98 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# openpyxl   ------------------------------     0 B/245.03 KiB
# python-docx ------------------------------     0 B/247.06 KiB
# bcrypt     ------------------------------     0 B/271.72 KiB
# googleapis-common-protos ------------------------------     0 B/290.54 KiB
# rich       ------------------------------     0 B/302.70 KiB
# protobuf   ------------------------------     0 B/315.88 KiB
# yarl       ------------------------------     0 B/357.25 KiB
# rpds-py    ------------------------------     0 B/381.67 KiB
# prompt-toolkit ------------------------------     0 B/382.26 KiB
# pydantic   ------------------------------     0 B/452.71 KiB
# pyyaml     ------------------------------     0 B/787.73 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# aiohttp    ------------------------------     0 B/1.67 MiB
# lxml       ------------------------------     0 B/4.98 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# python-docx ------------------------------ 30.88 KiB/247.06 KiB
# lance-namespace-urllib3-client ------------------------------ 30.89 KiB/271.45 KiB
# bcrypt     ------------------------------ 30.88 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 14.87 KiB/290.54 KiB
# rich       ------------------------------ 30.89 KiB/302.70 KiB
# protobuf   ------------------------------ 30.91 KiB/315.88 KiB
# pypdf      ------------------------------ 14.92 KiB/322.81 KiB
# jiter      ------------------------------ 14.92 KiB/350.75 KiB
# yarl       ------------------------------ 30.92 KiB/357.25 KiB
# rpds-py    ------------------------------ 20.51 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/382.26 KiB
# watchfiles ------------------------------ 14.91 KiB/445.39 KiB
# httptools  ------------------------------ 15.89 KiB/445.92 KiB
# pydantic   ------------------------------ 30.88 KiB/452.71 KiB
# crewai     ------------------------------ 30.85 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 30.90 KiB/473.85 KiB
# mpmath     ------------------------------ 32.00 KiB/523.63 KiB
# huggingface-hub ------------------------------ 16.00 KiB/540.36 KiB
# crewai-tools ------------------------------ 16.00 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# openpyxl   ------------------------------ 30.88 KiB/245.03 KiB
# python-docx ------------------------------ 46.88 KiB/247.06 KiB
# lance-namespace-urllib3-client ------------------------------ 78.89 KiB/271.45 KiB
# bcrypt     ------------------------------ 98.55 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 30.87 KiB/290.54 KiB
# rich       ------------------------------ 46.89 KiB/302.70 KiB
# protobuf   ------------------------------ 109.78 KiB/315.88 KiB
# pypdf      ------------------------------ 78.92 KiB/322.81 KiB
# jiter      ------------------------------ 94.92 KiB/350.75 KiB
# yarl       ------------------------------ 108.35 KiB/357.25 KiB
# rpds-py    ------------------------------ 92.06 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 62.88 KiB/382.26 KiB
# watchfiles ------------------------------ 93.21 KiB/445.39 KiB
# httptools  ------------------------------ 90.07 KiB/445.92 KiB
# pydantic   ------------------------------ 62.88 KiB/452.71 KiB
# crewai     ------------------------------ 62.85 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 84.33 KiB/473.85 KiB
# mpmath     ------------------------------ 94.96 KiB/523.63 KiB
# huggingface-hub ------------------------------ 60.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 16.00 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# openpyxl   ------------------------------ 46.88 KiB/245.03 KiB
# python-docx ------------------------------ 62.88 KiB/247.06 KiB
# lance-namespace-urllib3-client ------------------------------ 94.89 KiB/271.45 KiB
# bcrypt     ------------------------------ 204.00 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 46.87 KiB/290.54 KiB
# rich       ------------------------------ 46.89 KiB/302.70 KiB
# protobuf   ------------------------------ 173.88 KiB/315.88 KiB
# pypdf      ------------------------------ 142.92 KiB/322.81 KiB
# jiter      ------------------------------ 206.08 KiB/350.75 KiB
# yarl       ------------------------------ 220.35 KiB/357.25 KiB
# rpds-py    ------------------------------ 203.61 KiB/381.67 KiB
# prompt-toolkit ------------------------------ 91.95 KiB/382.26 KiB
# watchfiles ------------------------------ 221.21 KiB/445.39 KiB
# httptools  ------------------------------ 196.51 KiB/445.92 KiB
# pydantic   ------------------------------ 173.63 KiB/452.71 KiB
# crewai     ------------------------------ 78.85 KiB/462.12 KiB
# youtube-transcript-api ------------------------------ 192.18 KiB/473.85 KiB
# mpmath     ------------------------------ 142.96 KiB/523.63 KiB
# huggingface-hub ------------------------------ 204.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 33.54 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/152)
# openpyxl   ------------------------------ 62.88 KiB/245.03 KiB
# python-docx ------------------------------ 92.43 KiB/247.06 KiB
# lance-namespace-urllib3-client ------------------------------ 142.89 KiB/271.45 KiB
# bcrypt     ------------------------------ 268.00 KiB/271.72 KiB
# googleapis-common-protos ------------------------------ 94.13 KiB/290.54 KiB
# rich       ------------------------------ 62.89 KiB/302.70 KiB
# protobuf   ------------------------------ 237.78 KiB/315.88 KiB
# pypdf      ------------------------------ 222.92 KiB/322.81 KiB
# jiter      ------------------------------ 238.08 KiB/350.75 KiB
# yarl       ------------------------------ 268.35 KiB/357.25 KiB
# rpds-py    ------------------------------ 251.32 KiB/381.67 KiB
# prompt-toolkit ------------------------------
KiB
# protobuf   ------------------------------ 315.88 KiB/315.88 KiB
# prompt-toolkit ------------------------------ 235.95 KiB/382.26 KiB
# pydantic   ------------------------------ 429.63 KiB/452.71 KiB
# crewai     ------------------------------ 126.85 KiB/462.12 KiB
# mpmath     ------------------------------ 510.96 KiB/523.63 KiB
# huggingface-hub ------------------------------ 380.99 KiB/540.36 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/152)
# fsspec     ------------------------------ 30.91 KiB/197.76 KiB
# propcache  ------------------------------ 62.56 KiB/205.11 KiB
# cffi       ------------------------------ 79.41 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 48.00 KiB/214.83 KiB
# python-dateutil ------------------------------ 140.67 KiB/224.50 KiB
# frozenlist ------------------------------ 160.33 KiB/225.65 KiB
# tomli      ------------------------------ 190.21 KiB/237.31 KiB
# multidict  ------------------------------ 182.08 KiB/240.52 KiB
# openpyxl   ------------------------------ 142.21 KiB/245.03 KiB
# python-docx ------------------------------ 220.43 KiB/247.06 KiB
# lance-namespace-urllib3-client ------------------------------ 238.89 KiB/271.45 KiB
# googleapis-common-protos ------------------------------ 174.13 KiB/290.54 KiB
# rich       ------------------------------ 236.48 KiB/302.70 KiB
# protobuf   ------------------------------ 315.88 KiB/315.88 KiB
# prompt-toolkit ------------------------------ 267.95 KiB/382.26 KiB
# crewai     ------------------------------ 142.85 KiB/462.12 KiB
# mpmath     ------------------------------ 510.96 KiB/523.63 KiB
# huggingface-hub ------------------------------ 380.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 120.83 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/152)
# websockets ------------------------------     0 B/180.30 KiB
# fsspec     ------------------------------ 46.91 KiB/197.76 KiB
# propcache  ------------------------------ 94.56 KiB/205.11 KiB
# cffi       ------------------------------ 111.41 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 62.29 KiB/214.83 KiB
# python-dateutil ------------------------------ 172.67 KiB/224.50 KiB
# frozenlist ------------------------------ 176.23 KiB/225.65 KiB
# tomli      ------------------------------ 222.21 KiB/237.31 KiB
# multidict  ------------------------------ 207.00 KiB/240.52 KiB
# openpyxl   ------------------------------ 142.21 KiB/245.03 KiB
# python-docx ------------------------------ 236.43 KiB/247.06 KiB
# lance-namespace-urllib3-client ------------------------------ 254.89 KiB/271.45 KiB
# googleapis-common-protos ------------------------------ 174.13 KiB/290.54 KiB
# rich       ------------------------------ 252.48 KiB/302.70 KiB
# protobuf   ------------------------------ 315.88 KiB/315.88 KiB
# prompt-toolkit ------------------------------ 287.95 KiB/382.26 KiB
# crewai     ------------------------------ 142.85 KiB/462.12 KiB
# huggingface-hub ------------------------------ 396.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 136.83 KiB/723.68 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/152)
# websockets ------------------------------ 16.00 KiB/180.30 KiB
# fsspec     ------------------------------ 77.43 KiB/197.76 KiB
# propcache  ------------------------------ 110.56 KiB/205.11 KiB
# cffi       ------------------------------ 127.41 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 62.29 KiB/214.83 KiB
# python-dateutil ------------------------------ 188.67 KiB/224.50 KiB
# frozenlist ------------------------------ 189.92 KiB/225.65 KiB
# tomli      ------------------------------ 237.31 KiB/237.31 KiB
# multidict  ------------------------------ 223.00 KiB/240.52 KiB
# openpyxl   ------------------------------ 158.21 KiB/245.03 KiB
# lance-namespace-urllib3-client ------------------------------ 254.89 KiB/271.45 KiB
# googleapis-common-protos ------------------------------ 190.13 KiB/290.54 KiB
# rich       ------------------------------ 268.48 KiB/302.70 KiB
# protobuf   ------------------------------ 315.88 KiB/315.88 KiB
# prompt-toolkit ------------------------------ 287.95 KiB/382.26 KiB
# crewai     ------------------------------ 142.85 KiB/462.12 KiB
# huggingface-hub ------------------------------ 396.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 136.83 KiB/723.68 KiB
# pyvis      ------------------------------ 680.56 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/152)
# instructor ------------------------------     0 B/173.29 KiB
# websockets ------------------------------ 16.00 KiB/180.30 KiB
# fsspec     ------------------------------ 94.95 KiB/197.76 KiB
# propcache  ------------------------------ 126.56 KiB/205.11 KiB
# cffi       ------------------------------ 143.41 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------
KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (12/152)
# certifi    ------------------------------ 16.00 KiB/149.32 KiB
# oauthlib   ------------------------------ 16.00 KiB/156.31 KiB
# instructor ------------------------------ 14.91 KiB/173.29 KiB
# websockets ------------------------------ 48.00 KiB/180.30 KiB
# fsspec     ------------------------------ 126.95 KiB/197.76 KiB
# propcache  ------------------------------ 174.56 KiB/205.11 KiB
# cffi       ------------------------------ 175.41 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 94.29 KiB/214.83 KiB
# python-dateutil ------------------------------ 224.50 KiB/224.50 KiB
# frozenlist ------------------------------ 225.65 KiB/225.65 KiB
# openpyxl   ------------------------------ 158.21 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 206.13 KiB/290.54 KiB
# protobuf   ------------------------------ 315.88 KiB/315.88 KiB
# prompt-toolkit ------------------------------ 335.84 KiB/382.26 KiB
# crewai     ------------------------------ 158.85 KiB/462.12 KiB
# huggingface-hub ------------------------------ 412.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# pyvis      ------------------------------ 712.56 KiB/738.32 KiB
# regex      ------------------------------ 670.89 KiB/781.76 KiB
# pyyaml     ------------------------------ 734.84 KiB/787.73 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (12/152)
# certifi    ------------------------------ 16.00 KiB/149.32 KiB
# oauthlib   ------------------------------ 16.00 KiB/156.31 KiB
# instructor ------------------------------ 14.91 KiB/173.29 KiB
# websockets ------------------------------ 48.00 KiB/180.30 KiB
# fsspec     ------------------------------ 126.95 KiB/197.76 KiB
# propcache  ------------------------------ 174.56 KiB/205.11 KiB
# cffi       ------------------------------ 191.41 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 94.29 KiB/214.83 KiB
# python-dateutil ------------------------------ 224.50 KiB/224.50 KiB
# openpyxl   ------------------------------ 174.21 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 206.13 KiB/290.54 KiB
# protobuf   ------------------------------ 315.88 KiB/315.88 KiB
# prompt-toolkit ------------------------------ 335.84 KiB/382.26 KiB
# crewai     ------------------------------ 158.85 KiB/462.12 KiB
# huggingface-hub ------------------------------ 412.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# pyvis      ------------------------------ 728.56 KiB/738.32 KiB
# regex      ------------------------------ 670.89 KiB/781.76 KiB
# pyyaml     ------------------------------ 734.84 KiB/787.73 KiB
# ipython    ------------------------------ 472.56 KiB/812.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (12/152)
# certifi    ------------------------------ 32.00 KiB/149.32 KiB
# oauthlib   ------------------------------ 16.00 KiB/156.31 KiB
# instructor ------------------------------ 14.91 KiB/173.29 KiB
# websockets ------------------------------ 48.00 KiB/180.30 KiB
# fsspec     ------------------------------ 126.95 KiB/197.76 KiB
# propcache  ------------------------------ 174.56 KiB/205.11 KiB
# cffi       ------------------------------ 191.41 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 94.29 KiB/214.83 KiB
# openpyxl   ------------------------------ 174.21 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 222.13 KiB/290.54 KiB
# protobuf   ------------------------------ 315.88 KiB/315.88 KiB
# prompt-toolkit ------------------------------ 335.84 KiB/382.26 KiB
# crewai     ------------------------------ 158.85 KiB/462.12 KiB
# huggingface-hub ------------------------------ 412.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# pyvis      ------------------------------ 728.56 KiB/738.32 KiB
# regex      ------------------------------ 686.89 KiB/781.76 KiB
# pyyaml     ------------------------------ 741.62 KiB/787.73 KiB
# ipython    ------------------------------ 489.14 KiB/812.32 KiB
# openai     ------------------------------ 253.28 KiB/1.02 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (12/152)
# docker     ------------------------------     0 B/144.31 KiB
# charset-normalizer ------------------------------     0 B/148.00 KiB
# certifi    ------------------------------ 32.00 KiB/149.32 KiB
# oauthlib   ------------------------------ 16.00 KiB/156.31 KiB
# instructor ------------------------------ 30.63 KiB/173.29 KiB
# websockets ------------------------------ 62.36 KiB/180.30 KiB
# fsspec     ------------------------------ 141.43 KiB/197.76 KiB
# propcache  ------------------------------ 190.56 KiB/205.11 KiB
# cffi       ------------------------------ 207.41 KiB/210.52 KiB
# opentelemetry-semantic-conventions ------------------------------ 94.29 KiB/214.83 KiB
# openpyxl   ------------------------------ 174.21 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 222.13 KiB/290.54 KiB
# prompt-toolkit ------------------------------ 351.95 KiB/382.26 KiB
# crewai     ------------------------------ 158.85 KiB/462.12 KiB
# huggingface-hub ------------------------------ 428.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# pyvis      ------------------------------ 730.39 KiB/738.32 KiB
# regex      ------------------------------ 686.89 KiB/781.76 KiB
# pyyaml     ------------------------------ 741.62 KiB/787.73 KiB
# ipython    ------------------------------ 489.14 KiB/812.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (12/152)
# urllib3    ------------------------------ 9.82 KiB/128.50 KiB
# opentelemetry-sdk ------------------------------ 16.00 KiB/129.46 KiB
# orjson     ------------------------------ 14.92 KiB/130.32 KiB
# jinja2     ------------------------------ 16.00 KiB/131.74 KiB
# docker     ------------------------------ 14.62 KiB/144.31 KiB
# charset-normalizer ------------------------------ 32.00 KiB/148.00 KiB
# certifi    ------------------------------ 66.10 KiB/149.32 KiB
# oauthlib   ------------------------------ 48.00 KiB/156.31 KiB
# instructor ------------------------------ 30.63 KiB/173.29 KiB
# websockets ------------------------------ 95.76 KiB/180.30 KiB
# fsspec     ------------------------------ 189.43 KiB/197.76 KiB
# propcache  ------------------------------ 205.11 KiB/205.11 KiB
# opentelemetry-semantic-conventions ------------------------------ 110.29 KiB/214.83 KiB
# openpyxl   ------------------------------ 190.21 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 222.13 KiB/290.54 KiB
# prompt-toolkit ------------------------------ 363.70 KiB/382.26 KiB
# crewai     ------------------------------ 190.52 KiB/462.12 KiB
# huggingface-hub ------------------------------ 444.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 160.00 KiB/723.68 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (12/152)
# urllib3    ------------------------------ 9.82 KiB/128.50 KiB
# opentelemetry-sdk ------------------------------ 16.00 KiB/129.46 KiB
# orjson     ------------------------------ 30.92 KiB/130.32 KiB
# jinja2     ------------------------------ 16.00 KiB/131.74 KiB
# docker     ------------------------------ 14.62 KiB/144.31 KiB
# charset-normalizer ------------------------------ 32.00 KiB/148.00 KiB
# certifi    ------------------------------ 66.10 KiB/149.32 KiB
# oauthlib   ------------------------------ 48.00 KiB/156.31 KiB
# instructor ------------------------------ 30.63 KiB/173.29 KiB
# websockets ------------------------------ 95.76 KiB/180.30 KiB
# fsspec     ------------------------------ 189.43 KiB/197.76 KiB
# propcache  ------------------------------ 205.11 KiB/205.11 KiB
# opentelemetry-semantic-conventions ------------------------------ 110.29 KiB/214.83 KiB
# openpyxl   ------------------------------ 190.21 KiB/245.03 KiB
# googleapis-common-protos ------------------------------ 238.13 KiB/290.54 KiB
# crewai     ------------------------------ 190.52 KiB/462.12 KiB
# huggingface-hub ------------------------------ 460.99 KiB/540.36 KiB
# crewai-tools ------------------------------ 176.00 KiB/723.68 KiB
# pyvis      ------------------------------ 738.32 KiB/738.32 KiB
# ⠧ Preparing packages... (149/152) 32.49 MiB/45.33 MiB
# lancedb    ------------------------------ 42.17 MiB/45.04 MiB
# ⠇ Preparing packages... (150/152) 32.49 MiB/45.33 MiB
# lancedb    ------------------------------ 44.87 MiB/45.04 MiB
# ⠋ Preparing packages... (150/152) 32.49 MiB/45.33 MiB
# lancedb    ------------------------------ 44.90 MiB/45.04 MiB
# ⠋ Preparing packages... (150/152) 35.38 MiB/45.33 MiB
# lancedb    ------------------------------ 44.90 MiB/45.04 MiB
# ⠋ Preparing packages... (150/152) 35.42 MiB/45.33 MiB
# lancedb    ------------------------------ 44.90 MiB/45.04 MiB
# ⠋ Preparing packages... (150/152) 35.43 MiB/45.33 MiB
# lancedb    ------------------------------ 44.90 MiB/45.04 MiB
# ⠋ Preparing packages... (150/152) 35.45 MiB/45.33 MiB
# lancedb    ------------------------------ 44.90 MiB/45.04 MiB
# ⠋ Preparing packages... (150/152) 35.68 MiB/45.33 MiB
# lancedb    ------------------------------ 44.92 MiB/45.04 MiB
# ⠋ Preparing packages... (150/152) 40.09 MiB/45.33 MiB
# lancedb    ------------------------------ 44.93 MiB/45.04 MiB
# ⠋ Preparing packages... (150/152) 41.95 MiB/45.33 MiB
# ⠙ Preparing packages... (151/152) 41.95 MiB/45.33 MiB
# ⠙ Preparing packages... (151/152) 41.95 MiB/45.33 MiB
# ⠙ Preparing packages... (151/152) 42.03 MiB/45.33 MiB
# ⠙ Preparing packages... (151/152) 42.05 MiB/45.33 MiB
# ⠙ Preparing packages... (151/152) 42.06 MiB/45.33 MiB
# ⠹ Preparing packages... (151/152) 43.57 MiB/45.33 MiB
# ⠹ Preparing packages... (151/152) 44.05 MiB/45.33 MiB
# Prepared 152 packages in 5.70s
# Installed 152 packages in 353ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.3
#  + aiosignal==1.4.0
#  + annotated-types==0.7.0
#  + anyio==4.12.1
#  + appdirs==1.4.4
#  + asttokens==3.0.1
#  + attrs==25.4.0
#  + backoff==2.2.1
#  + bcrypt==5.0.0
#  + beautifulsoup4==4.14.3
#  + blinker==1.9.0
#  + build==1.4.0
#  + certifi==2026.1.4
#  + cffi==2.0.0
#  + charset-normalizer==3.4.4
#  + chromadb==1.1.1
#  + click==8.3.1
#  + crewai==0.203.2
#  + crewai-tools==0.76.0
#  + cryptography==46.0.4
#  + decorator==5.2.1
#  + defusedxml==0.7.1
#  + deprecation==2.1.0
#  + diskcache==5.6.3
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.17.0
#  + durationpy==0.10
#  + et-xmlfile==2.0.0
#  + executing==2.2.1
#  + filelock==3.20.3
#  + flatbuffers==25.12.19
#  + frozenlist==1.8.0
#  + fsspec==2026.2.0
#  + googleapis-common-protos==1.72.0
#  + grpcio==1.78.0
#  + h11==0.16.0
#  + hf-xet==1.2.0
#  + httpcore==1.0.9
#  + httptools==0.7.1
#  + httpx==0.28.1
#  + huggingface-hub==1.4.1
#  + idna==3.11
#  + importlib-metadata==8.7.1
#  + importlib-resources==6.5.2
#  + instructor==1.14.5
#  + ipython==8.38.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.11.1
#  + json-repair==0.25.2
#  + json5==0.13.0
#  + jsonpickle==4.1.1
#  + jsonref==1.1.0
#  + jsonschema==4.26.0
#  + jsonschema-specifications==2025.9.1
#  + kubernetes==35.0.0
#  + lance-namespace==0.4.5
#  + lance-namespace-urllib3-client==0.4.5
#  + lancedb==0.29.1
#  + litellm==1.74.9
#  + lxml==6.0.2
#  + markdown-it-py==4.0.0
#  + markupsafe==3.0.3
#  + matplotlib-inline==0.2.1
#  + mdurl==0.1.2
#  + mmh3==5.2.0
#  + mpmath==1.3.0
#  + multidict==6.7.1
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + numpy==2.2.6
#  + oauthlib==3.3.1
#  + onnxruntime==1.24.1
#  + openai==2.17.0
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.39.1
#  + opentelemetry-exporter-otlp-proto-common==1.39.1
#  + opentelemetry-exporter-otlp-proto-grpc==1.39.1
#  + opentelemetry-exporter-otlp-proto-http==1.39.1
#  + opentelemetry-proto==1.39.1
#  + opentelemetry-sdk==1.39.1
#  + opentelemetry-semantic-conventions==0.60b1
#  + orjson==3.11.7
#  + overrides==7.7.0
#  + packaging==26.0
#  + parso==0.8.5
#  + pdfminer-six==20251230
#  + pdfplumber==0.11.9
#  + pexpect==4.9.0
#  + pillow==12.1.0
#  + portalocker==2.7.0
#  + posthog==5.4.0
#  + prompt-toolkit==3.0.52
#  + propcache==0.4.1
#  + protobuf==6.33.5
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==23.0.0
#  + pybase64==1.4.3
#  + pycparser==3.0
#  + pydantic==2.12.5
#  + pydantic-core==2.41.5
#  + pydantic-settings==2.12.0
#  + pygments==2.19.2
#  + pyjwt==2.11.0
#  + pypdf==6.7.0
#  + pypdfium2==5.4.0
#  + pypika==0.51.1
#  + pyproject-hooks==1.2.0
#  + python-dateutil==2.9.0.post0
#  + python-docx==1.2.0
#  + python-dotenv==1.2.1
#  + pytube==15.0.0
#  + pyvis==0.3.2
#  + pyyaml==6.0.3
#  + referencing==0.37.0
#  + regex==2026.1.15
#  + requests==2.32.5
#  + requests-oauthlib==2.0.0
#  + rich==14.3.2
#  + rpds-py==0.30.0
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.8.3
#  + stack-data==0.6.3
#  + stagehand==3.5.0
#  + sympy==1.14.0
#  + tenacity==9.1.4
#  + tiktoken==0.12.0
#  + tokenizers==0.22.2
#  + tomli==2.4.0
#  + tomli-w==1.2.0
#  + tqdm==4.67.3
#  + traitlets==5.14.3
#  + typer==0.21.1
#  + typer-slim==0.21.1
#  + typing-extensions==4.15.0
#  + typing-inspection==0.4.2
#  + urllib3==2.6.3
#  + uv==0.10.0
#  + uvicorn==0.40.0
#  + uvloop==0.22.1
#  + watchfiles==1.1.1
#  + wcwidth==0.6.0
#  + websocket-client==1.9.0
#  + websockets==16.0
#  + yarl==1.22.0
#  + youtube-transcript-api==1.2.4
#  + zipp==3.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 7ae905f7-7ce1-4da8-aa55-a35fd5a68f4d                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Task: Conduct a thorough research about AI LLMs Make sure you find any      │
# │  interesting and relevant information given the current year is 2024.        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
#     Status: Executing Task...
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Final Answer:                                                               │
# │  1. **Multimodal Capabilities**: Recent advancements in AI large language    │
# │  models (LLMs) have introduced multimodal capabilities, allowing them to     │
# │  process and generate not only text but also images, audio, and video.       │
# │  Models like OpenAI’s GPT-4 have demonstrated the ability to understand and  │
# │  generate content across these varied formats, enhancing their               │
# │  applicability in fields such as education and entertainment.                │
# │                                                                              │
# │  2. **Fine-tuning Techniques**: Advanced fine-tuning techniques, such as     │
# │  Reinforcement Learning from Human Feedback (RLHF), are becoming more        │
# │  prevalent. This approach helps LLMs align better with human values and      │
# │  preferences, improving their performance in generating more accurate and    │
# │  contextually relevant responses.                                            │
# │                                                                              │
# │  3. **Scalability and Efficiency**: Recent efforts have focused on making    │
# │  LLMs more scalable and efficient. For instance, innovations in model        │
# │  distillation and quantization are enabling developers to create smaller,    │
# │  faster, and more energy-efficient models without significantly              │
# │  compromising on performance, making AI more accessible.                     │
# │                                                                              │
# │  4. **Response Adaptation**: LLMs are now incorporating adaptive response    │
# │  mechanisms. This allows them to modify their replies based on user context  │
# │  and feedback over time, providing a more personalized interaction           │
# │  experience and reflecting dynamic changes in user preferences.              │
# │                                                                              │
# │  5. **Safety and Bias Mitigation**: With growing concerns about AI bias and  │
# │  safety, state-of-the-art LLMs now incorporate sophisticated bias detection  │
# │  and mitigation strategies. These include pre-emptive checks during          │
# │  training and post-training evaluations to identify and reduce biased        │
# │  outputs, striving for ethical AI deployment.                                │
# │                                                                              │
# │  6. **Real-time Collaboration Tools**: Powerful LLMs are now integrated      │
# │  into collaborative tools such as coding platforms (e.g., GitHub Copilot)    │
# │  that assist developers in real-time. These models can suggest code          │
# │  snippets, explain functions, and optimize code, enhancing productivity in   │
# │  software development.                                                       │
# │                                                                              │
# │  7. **Language Support Expansion**: Current LLMs are designed to support a   │
# │  broader array of languages and dialects, promoting inclusivity and          │
# │  accessibility in AI applications. The expansion includes support for        │
# │  low-resource languages, facilitating global communication and usage.        │
# │                                                                              │
# │  8. **Automated Content Creation**: The use of LLMs for automated content    │
# │  creation is on the rise. Industries are leveraging AI to generate           │
# │  articles, marketing copy, and even news reports. Tools like Jasper and      │
# │  Copy.ai are becoming more sophisticated, prompting discussions on the       │
# │  future of creative professions.                                             │
# │                                                                              │
# │  9. **AI in Healthcare**: LLMs are making significant inroads into the       │
# │  healthcare sector by assisting medical professionals with patient records   │
# │  analysis, clinical decision support, and personalized patient               │
# │  interactions, marking a transformative shift in how healthcare services     │
# │  are delivered.                                                              │
# │                                                                              │
# │  10. **Legal and Ethical Frameworks**: As LLM capabilities expand, there is  │
# │  an increasing focus on establishing legal and ethical frameworks            │
# │  surrounding their use. Policymakers are working on regulation proposals     │
# │  that ensure responsible deployment, prompting discussions on intellectual   │
# │  property, accountability, and transparency in AI-generated content.         │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
#     Assigned to: AI LLMs Senior Data Researcher
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: research_task                                                         │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 564e3cc7-7a68-4e44-bb4d-464f30e6fd44)
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Task: Review the context you got and expand each topic into a full section  │
# │  for a report. Make sure the report is detailed and contains any and all     │
# │  relevant information.                                                       │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 564e3cc7-7a68-4e44-bb4d-464f30e6fd44)
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 564e3cc7-7a68-4e44-bb4d-464f30e6fd44)
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  # Comprehensive Report on Recent Advancements in AI Large Language Models   │
# │  (LLMs)                                                                      │
# │                                                                              │
# │  ## 1. Multimodal Capabilities                                               │
# │  Recent advancements in AI large language models (LLMs) have introduced      │
# │  remarkable multimodal capabilities, enabling them to process and generate   │
# │  diverse formats of content beyond traditional text. These models,           │
# │  exemplified by OpenAI's GPT-4, can now interpret and create images, audio,  │
# │  and video, significantly expanding their utility across various sectors.    │
# │  In education, for instance, multimodal LLMs can provide interactive         │
# │  learning experiences by generating visual aids alongside text               │
# │  explanations. In the entertainment industry, they can create dynamic        │
# │  narratives that integrate auditory and visual elements, tailoring           │
# │  experiences to audiences' preferences. This multimodal approach enhances    │
# │  user engagement and opens doors for creative applications that reshape      │
# │  interaction with technology.                                                │
# │                                                                              │
# │  ## 2. Fine-tuning Techniques                                                │
# │  Advanced fine-tuning techniques have emerged as crucial methods for         │
# │  enhancing the performance of LLMs, with Reinforcement Learning from Human   │
# │  Feedback (RLHF) gaining prominence. This innovative approach allows models  │
# │  to better align their outputs with human values and preferences, thus       │
# │  increasing the quality and relevance of responses. The RLHF process         │
# │  involves training models on a dataset enriched with human feedback to       │
# │  reinforce desirable outputs while minimizing the occurrence of undesired    │
# │  responses. This iterative refinement not only boosts accuracy but also      │
# │  makes LLMs more intuitive in understanding nuanced human communication,     │
# │  positioning them as more effective tools for various applications, from     │
# │  customer support to content generation.                                     │
# │                                                                              │
# │  ## 3. Scalability and Efficiency                                            │
# │  The focus on scalability and efficiency is increasingly vital in the        │
# │  development of LLMs. Innovations in model distillation and quantization     │
# │  have made it possible to produce smaller, faster models that consume less   │
# │  energy without compromising performance significantly. These techniques     │
# │  involve simplifying complex models while preserving essential               │
# │  capabilities. As a result, developers can deploy AI solutions that are not  │
# │  only effective but also more sustainable, reducing the carbon footprint     │
# │  associated with high-complexity computations. This progress democratizes    │
# │  access to AI technologies, allowing smaller organizations to leverage       │
# │  advanced LLMs and foster innovation at different scales.                    │
# │                                                                              │
# │  ## 4. Response Adaptation                                                   │
# │  The evolution of adaptive response mechanisms in LLMs marks a significant   │
# │  leap toward personalized user experiences. Current models have begun to     │
# │  incorporate feedback loops that enable them to adjust responses based on    │
# │  the user's previous interactions and contextual information. This           │
# │  adaptability allows LLMs to engage in more meaningful conversations,        │
# │  resulting in increased user satisfaction and engagement. By evolving with   │
# │  user preferences, LLMs can provide tailored suggestions and information,    │
# │  making interactions more relevant and effective over time. Such             │
# │  user-centric models enhance the overarching goal of AI: to furnish          │
# │  individuals with personalized support and solutions in real-time.           │
# │                                                                              │
# │  ## 5. Safety and Bias Mitigation                                            │
# │  As concerns regarding bias and safety in AI technologies escalate, leading  │
# │  LLMs are implementing sophisticated strategies for bias detection and       │
# │  mitigation. These strategies include conducting pre-emptive checks during   │
# │  the training phase and carrying out thorough evaluations post-training to   │
# │  identify and rectify any biased outputs. By integrating diverse datasets    │
# │  and fostering inclusivity in the training process, developers aim to        │
# │  reduce the chances of propagating stereotypes or discriminatory language.   │
# │  The pursuit of ethical AI deployment is becoming a priority, prompting      │
# │  organizations to prioritize transparency and accountability to build trust  │
# │  with users and stakeholders.                                                │
# │                                                                              │
# │  ## 6. Real-time Collaboration Tools                                         │
# │  The integration of powerful LLMs into real-time collaboration tools         │
# │  exemplifies their practical applications in enhancing productivity.         │
# │  Platforms such as GitHub Copilot leverage LLMs to assist developers by      │
# │  suggesting code snippets, providing explanations of complex functions, and  │
# │  optimizing existing code. This real-time support helps speed up the         │
# │  software development process, allowing developers to focus on higher-level  │
# │  problem-solving and creativity. As these AI tools continue to evolve, they  │
# │  not only augment human capabilities but also foster better collaboration    │
# │  among team members, paving the way for innovative solutions in technology.  │
# │                                                                              │
# │  ## 7. Language Support Expansion                                            │
# │  Current LLMs are designed with an emphasis on expanding language support,   │
# │  enabling wider accessibility and inclusivity in AI applications. This       │
# │  enhancement involves incorporating a broader array of languages and         │
# │  dialects, including low-resource languages often overlooked in AI           │
# │  development. By doing so, organizations facilitate global communication     │
# │  and ensure that diverse linguistic communities can take advantage of the    │
# │  benefits offered by AI. The capability to understand and generate content   │
# │  in multiple languages represents a significant step toward breaking down    │
# │  barriers and fostering a more connected world.                              │
# │                                                                              │
# │  ## 8. Automated Content Creation                                            │
# │  The rise of LLMs in automated content creation is revolutionizing various   │
# │  industries, from marketing to journalism. Organizations are increasingly    │
# │  leveraging AI to generate high-quality articles, marketing copy, and news   │
# │  reports, streamlining content production processes. Tools such as Jasper    │
# │  and Copy.ai exemplify the growing sophistication of AI in creative tasks,   │
# │  enabling businesses to produce tailored content at scale while reducing     │
# │  overhead costs. However, this advancement also raises critical discussions  │
# │  about the future of creative professions and the ethical considerations     │
# │  surrounding AI-generated content, emphasizing the need for regulation and   │
# │  standards in this evolving landscape.                                       │
# │                                                                              │
# │  ## 9. AI in Healthcare                                                      │
# │  The application of LLMs in the healthcare sector signifies a                │
# │  transformative shift in service delivery and patient care. These models     │
# │  are assisting medical professionals through the analysis of patient         │
# │  records, providing clinical decision support, and enhancing personalized    │
# │  patient interactions. By processing vast amounts of medical data rapidly,   │
# │  LLMs can help clinicians make informed decisions, improve diagnostic        │
# │  accuracy, and foster stronger patient-provider relationships. This          │
# │  integration of AI into healthcare not only enhances operational efficiency  │
# │  but also contributes to improved health outcomes, marking a notable         │
# │  advancement in medical practices.                                           │
# │                                                                              │
# │  ## 10. Legal and Ethical Frameworks                                         │
# │  As the capabilities of LLMs expand, there is an increasing urgency to       │
# │  establish comprehensive legal and ethical frameworks governing their use.   │
# │  Policymakers and stakeholders are actively engaging in discussions about    │
# │  regulatory proposals that promote responsible AI deployment, addressing     │
# │  concerns related to intellectual property, accountability, and              │
# │  transparency. These frameworks aim to strike a balance between fostering    │
# │  innovation and protecting individuals' rights in the face of rapid          │
# │  technological advancement. By laying down guidelines for ethical AI use,    │
# │  society can help ensure that the benefits of LLMs are realized while        │
# │  minimizing risks and preserving human dignity.                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: research_task (ID: 20085404-23c1-4def-9c03-669a5dbe3265)
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: reporting_task (ID: 564e3cc7-7a68-4e44-bb4d-464f30e6fd44)
#     Assigned to: AI LLMs Reporting Analyst
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: reporting_task                                                        │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 7ae905f7-7ce1-4da8-aa55-a35fd5a68f4d                                    │
# │  Tool Args:                                                                  │
# │  Final Output: # Comprehensive Report on Recent Advancements in AI Large     │
# │  Language Models (LLMs)                                                      │
# │                                                                              │
# │  ## 1. Multimodal Capabilities                                               │
# │  Recent advancements in AI large language models (LLMs) have introduced      │
# │  remarkable multimodal capabilities, enabling them to process and generate   │
# │  diverse formats of content beyond traditional text. These models,           │
# │  exemplified by OpenAI's GPT-4, can now interpret and create images, audio,  │
# │  and video, significantly expanding their utility across various sectors.    │
# │  In education, for instance, multimodal LLMs can provide interactive         │
# │  learning experiences by generating visual aids alongside text               │
# │  explanations. In the entertainment industry, they can create dynamic        │
# │  narratives that integrate auditory and visual elements, tailoring           │
# │  experiences to audiences' preferences. This multimodal approach enhances    │
# │  user engagement and opens doors for creative applications that reshape      │
# │  interaction with technology.                                                │
# │                                                                              │
# │  ## 2. Fine-tuning Techniques                                                │
# │  Advanced fine-tuning techniques have emerged as crucial methods for         │
# │  enhancing the performance of LLMs, with Reinforcement Learning from Human   │
# │  Feedback (RLHF) gaining prominence. This innovative approach allows models  │
# │  to better align their outputs with human values and preferences, thus       │
# │  increasing the quality and relevance of responses. The RLHF process         │
# │  involves training models on a dataset enriched with human feedback to       │
# │  reinforce desirable outputs while minimizing the occurrence of undesired    │
# │  responses. This iterative refinement not only boosts accuracy but also      │
# │  makes LLMs more intuitive in understanding nuanced human communication,     │
# │  positioning them as more effective tools for various applications, from     │
# │  customer support to content generation.                                     │
# │                                                                              │
# │  ## 3. Scalability and Efficiency                                            │
# │  The focus on scalability and efficiency is increasingly vital in the        │
# │  development of LLMs. Innovations in model distillation and quantization     │
# │  have made it possible to produce smaller, faster models that consume less   │
# │  energy without compromising performance significantly. These techniques     │
# │  involve simplifying complex models while preserving essential               │
# │  capabilities. As a result, developers can deploy AI solutions that are not  │
# │  only effective but also more sustainable, reducing the carbon footprint     │
# │  associated with high-complexity computations. This progress democratizes    │
# │  access to AI technologies, allowing smaller organizations to leverage       │
# │  advanced LLMs and foster innovation at different scales.                    │
# │                                                                              │
# │  ## 4. Response Adaptation                                                   │
# │  The evolution of adaptive response mechanisms in LLMs marks a significant   │
# │  leap toward personalized user experiences. Current models have begun to     │
# │  incorporate feedback loops that enable them to adjust responses based on    │
# │  the user's previous interactions and contextual information. This           │
# │  adaptability allows LLMs to engage in more meaningful conversations,        │
# │  resulting in increased user satisfaction and engagement. By evolving with   │
# │  user preferences, LLMs can provide tailored suggestions and information,    │
# │  making interactions more relevant and effective over time. Such             │
# │  user-centric models enhance the overarching goal of AI: to furnish          │
# │  individuals with personalized support and solutions in real-time.           │
# │                                                                              │
# │  ## 5. Safety and Bias Mitigation                                            │
# │  As concerns regarding bias and safety in AI technologies escalate, leading  │
# │  LLMs are implementing sophisticated strategies for bias detection and       │
# │  mitigation. These strategies include conducting pre-emptive checks during   │
# │  the training phase and carrying out thorough evaluations post-training to   │
# │  identify and rectify any biased outputs. By integrating diverse datasets    │
# │  and fostering inclusivity in the training process, developers aim to        │
# │  reduce the chances of propagating stereotypes or discriminatory language.   │
# │  The pursuit of ethical AI deployment is becoming a priority, prompting      │
# │  organizations to prioritize transparency and accountability to build trust  │
# │  with users and stakeholders.                                                │
# │                                                                              │
# │  ## 6. Real-time Collaboration Tools                                         │
# │  The integration of powerful LLMs into real-time collaboration tools         │
# │  exemplifies their practical applications in enhancing productivity.         │
# │  Platforms such as GitHub Copilot leverage LLMs to assist developers by      │
# │  suggesting code snippets, providing explanations of complex functions, and  │
# │  optimizing existing code. This real-time support helps speed up the         │
# │  software development process, allowing developers to focus on higher-level  │
# │  problem-solving and creativity. As these AI tools continue to evolve, they  │
# │  not only augment human capabilities but also foster better collaboration    │
# │  among team members, paving the way for innovative solutions in technology.  │
# │                                                                              │
# │  ## 7. Language Support Expansion                                            │
# │  Current LLMs are designed with an emphasis on expanding language support,   │
# │  enabling wider accessibility and inclusivity in AI applications. This       │
# │  enhancement involves incorporating a broader array of languages and         │
# │  dialects, including low-resource languages often overlooked in AI           │
# │  development. By doing so, organizations facilitate global communication     │
# │  and ensure that diverse linguistic communities can take advantage of the    │
# │  benefits offered by AI. The capability to understand and generate content   │
# │  in multiple languages represents a significant step toward breaking down    │
# │  barriers and fostering a more connected world.                              │
# │                                                                              │
# │  ## 8. Automated Content Creation                                            │
# │  The rise of LLMs in automated content creation is revolutionizing various   │
# │  industries, from marketing to journalism. Organizations are increasingly    │
# │  leveraging AI to generate high-quality articles, marketing copy, and news   │
# │  reports, streamlining content production processes. Tools such as Jasper    │
# │  and Copy.ai exemplify the growing sophistication of AI in creative tasks,   │
# │  enabling businesses to produce tailored content at scale while reducing     │
# │  overhead costs. However, this advancement also raises critical discussions  │
# │  about the future of creative professions and the ethical considerations     │
# │  surrounding AI-generated content, emphasizing the need for regulation and   │
# │  standards in this evolving landscape.                                       │
# │                                                                              │
# │  ## 9. AI in Healthcare                                                      │
# │  The application of LLMs in the healthcare sector signifies a                │
# │  transformative shift in service delivery and patient care. These models     │
# │  are assisting medical professionals through the analysis of patient         │
# │  records, providing clinical decision support, and enhancing personalized    │
# │  patient interactions. By processing vast amounts of medical data rapidly,   │
# │  LLMs can help clinicians make informed decisions, improve diagnostic        │
# │  accuracy, and foster stronger patient-provider relationships. This          │
# │  integration of AI into healthcare not only enhances operational efficiency  │
# │  but also contributes to improved health outcomes, marking a notable         │
# │  advancement in medical practices.                                           │
# │                                                                              │
# │  ## 10. Legal and Ethical Frameworks                                         │
# │  As the capabilities of LLMs expand, there is an increasing urgency to       │
# │  establish comprehensive legal and ethical frameworks governing their use.   │
# │  Policymakers and stakeholders are actively engaging in discussions about    │
# │  regulatory proposals that promote responsible AI deployment, addressing     │
# │  concerns related to intellectual property, accountability, and              │
# │  transparency. These frameworks aim to strike a balance between fostering    │
# │  innovation and protecting individuals' rights in the face of rapid          │
# │  technological advancement. By laying down guidelines for ethical AI use,    │
# │  society can help ensure that the benefits of LLMs are realized while        │
# │  minimizing risks and preserving human dignity.                              │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
#
#
# ╭────────────────────────────── Execution Traces ──────────────────────────────╮
# │                                                                              │
# │  🔍 Detailed execution traces are available!                                 │
# │                                                                              │
# │  View insights including:                                                    │
# │    • Agent decision-making process                                           │
# │    • Task execution flow and timing                                          │
# │    • Tool usage details                                                      │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# Would you like to view your execution traces? [y/N] (20s timeout):

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow

# %%
! ls -1 new_flow

# %%
! ls -1 new_flow/src/new_flow/
